# %% [markdown]
# ## <span style='color:Yellow'> Name : </span> `Amartyaraj Kumar`
# #  <span style='color:Yellow'> Roll : </span>  `19029`
# #### <span style='color:Yellow'> Date : </span>  `05/09/22`

# %% [markdown]
# ### This Notebook has got two parts.
# ### You may want to work on the Part I first, which is at the bottom of this page.
# ### Then come back to the Part II  in the top.

# %% [markdown]
# # Part II Problem Exercises

# %% [markdown]
# # Exercise: Using `requests`
#
# 1. Download and install `requests` from PyPI using `pip`.
#     If `pip` is broken, try instead `python3 -m pip install WHATEVER`
# 2. In a Python program, `import requests`
# 3. Use `requests.get` to retrieve from your favorite Web site. For example, https://www.genius.com/ or https://www.python.org/events/.
# 4. Check the status code, [hint: `status_code`]
# 5. Print the first 100 bytes of the content (`r.content`)
# 6. Use `requests.get` to try to get information from a URL that does not exist.
# 7. Show the status code.

# %%
# YOUR CODE HERE

# Use multiple shells as you may need
import requests

# %%
X = requests.get('https://genius.com/')
X.status_code
# Out:
# 200

# %%
print(X.content)
# Out:
# b'<!doctype html>\n<html>\n  <head>\n    <title>Genius | Song Lyrics &amp; Knowledge</title>\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta content=\'width=device-width,initial-scale=1\' name=\'viewport\'>\n\n  <meta name="apple-itunes-app" content="app-id=709482991">\n\n<link href="https://assets.genius.com/images/apple-touch-icon.png?1661974244" rel="apple-touch-icon" />\n\n\n  \n\n  <link href="https://assets.genius.com/images/apple-touch-icon.png?1661974244" rel="apple-touch-icon" />\n\n  \n\n  <!-- Mobile IE allows us to activate ClearType technology for smoothing fonts for easy reading -->\n  <meta http-equiv="cleartype" content="on">\n\n\n\n\n<META name="y_key" content="f63347d284f184b0">\n\n<meta property="og:site_name" content="Genius"/>\n<meta property="fb:app_id" content="265539304824" />\n<meta property="fb:pages" content="308252472676410" />\n\n<link title="Genius" type="application/opensearchdescription+xml" rel="search" href="https://ge
# ...

# %%
#Q7
Y = requests.get('https://amartyaraj1234123.com/')
Y.status_code
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\Users\user\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# c:\Users\user\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# c:\Users\user\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# ...

# %% [markdown]
# # Exercise: Character classification
#
# 1. Import the `string` module in Python.  Historically, this module used to have a lot of functionality, but most of that was moved into methods on the `str` (string) class.  However, it still defines a few different variables that can be useful.  For example, `string.digits` (all digits), `string.punctuation` (punctuation), and `string.ascii_letters` (letters).
# 2. Type those `string.digits` (all digits), `string.punctuation` (punctuation), and `string.ascii_letters` (letters) in individual shell and show the output before working on the exercise given below.
# 3. Define a dict with three keys -- `digits`, `punctuation`, and `letters`, and set the value to be 0 in each.
# 4. Ask the user to enter a string.
# 5. Go through the string, one character at a time:
#     - If the character is a digit, add 1 to the `digits` value
#     - If the character is punctuation, add 1 to the `punctuation` value
#     - If the character is letter, add 1 to the `letter` value
# 6. Print out the resulting dict

# %%
### YOU IMPORT THE MODULE
import string

# %%
### all digits code
string.digits
# Out:
# '0123456789'

# %%
## all punctuation code
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
### all ascii letters code
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
### YOUR CODE HERE, Sample OUTPUT is given Below
dictn = {'Digits':0,'Punctuation':0, 'Letters': 0}

user_in = input('enter your number \n')
word = user_in.strip()
for alphabet in word:
    if alphabet in string.punctuation:
        dictn['Punctuation'] = dictn['Punctuation'] +1 
    elif alphabet in string.digits:
        dictn['Digits'] = dictn['Digits'] +1
    elif alphabet in string.ascii_letters:
        dictn['Letters'] = dictn['Letters'] +1

print ('No of Punctuation :', dictn['Punctuation'])
print ('No of Ascii_letters :',dictn['Letters'])
print ('No of Digits :',dictn['Digits'])
# Out:
# enter your number
# AMasrtyajgxyasjxuhasucpedu487r348r828ey812p9ejq/;;.l;p'kdouqwhfoqugdo
# No of Punctuation : 6
# No of Ascii_letters : 50
# No of Digits : 13

# %% [markdown]
# # Part I Practice Exercises
#
# ### To make things easier, first work on the Practice Exercises given in the pdf file and enter them in cells below.

# %%
f = open('pg37431.txt')

text = f.read()
print(text)
# Out:
# The Project Gutenberg EBook of Pride and Prejudice, a play, by
# Mary Keith Medbery Mackaye
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.org
#
#
# Title: Pride and Prejudice, a play
#
# Author: Mary Keith Medbery Mackaye
#
# Release Date: September 15, 2011 [EBook #37431]
#
# Language: English
#
#
# *** START OF THIS PROJECT GUTENBERG EBOOK PRIDE AND PREJUDICE, A PLAY ***
#
#
#
#
# Produced by Chuck Greif and the Online Distributed
# Proofreading Team at http://www.pgdp.net (This book was
# produced from scanned images of public domain material
# from the Internet Archive.)
#
#
#
#
#
#
#
#
# _PRIDE AND PREJUDICE_
#
# _A PLAY_
#
# [Illustration: "_Mr. Darcy, I have never desired your good opinion, and
# you have certainly bestowed it most unwillingly._"]
#
#
#
#
# ...

# %%
#text

# %%
with open("pg37431.txt") as f:
    print(f.read(5))
# Out:
# The P

# %%
with open("pg37431.txt") as f:
    print(f.readline())
# Out:
# The Project Gutenberg EBook of Pride and Prejudice, a play, by

# %%
f = open('log.txt', 'w')

# %%
from datetime import datetime
import time
for i in range(0,10):
    print(datetime.now().strftime('%Y-%m-%d_%H:%M:%S - '),i)
    f.write(datetime.now().strftime('%Y-%m-%d_%H:%M:%S - '))
    time.sleep(1)
    f.write(str(i))
    f.write("\n")
f.close()
# Out:
# 2022-09-05_17:24:22 -  0
# 2022-09-05_17:24:23 -  1
# 2022-09-05_17:24:24 -  2
# 2022-09-05_17:24:25 -  3
# 2022-09-05_17:24:26 -  4
# 2022-09-05_17:24:27 -  5
# 2022-09-05_17:24:28 -  6
# 2022-09-05_17:24:29 -  7
# 2022-09-05_17:24:30 -  8
# 2022-09-05_17:24:31 -  9

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
temperature = [14.2, 16.4, 11.9, 12.5, 18.9, 22.1, 19.4, 23.1, 25.4, 18.1, 22.6, 17.2]
sales = [215.20, 325.00, 185.20, 330.20, 418.60, 520.25, 412.20, 614.60, 544.80, 421.40, 445.50, 408.10]
plt.scatter(temperature, sales, color='red')
plt.show()

# %%
plt.title('Ice-cream sales versus Temperature')
plt.xlabel('Sales')
plt.ylabel('Temperature')
plt.scatter(temperature, sales, color='red')
plt.show()

# %%
stock_price = [190.64, 190.09, 192.25,
191.79, 194.45, 196.45, 196.45, 196.42,
200.32, 200.32, 200.85, 199.2, 199.2,
199.2, 199.46, 201.46, 197.54, 201.12,
203.12, 203.12, 203.12, 202.83, 202.83,
203.36, 206.83, 204.9, 204.9, 204.9,
204.4, 204.06]

# %%
plt.plot(stock_price)
plt.title('Opening Stock Prices')
plt.xlabel('Days')
plt.ylabel('$ USD')
plt.show()

# %%
t = list(range(1, 31))
plt.plot(t, stock_price, marker='.',
color='red')
plt.xticks([1, 8, 15, 22, 28]);

# %%
stock_price = [190.64, 190.09, 192.25,
191.79, 194.45, 196.45, 196.45, 196.42,
200.32, 200.32, 200.85, 199.2, 199.2,
199.2, 199.46, 201.46, 197.54, 201.12,
203.12, 203.12, 203.12, 202.83, 202.83,
203.36, 206.83, 204.9, 204.9, 204.9,
204.4, 204.06]

t = list(range(1, 31))
import matplotlib.pyplot as plt
plt.title('Opening Stock Prices')
plt.xlabel('Days')
plt.ylabel('$ USD')
plt.plot(t, stock_price, marker='.', color='red')
plt.xticks([1, 8, 15, 22, 28])
plt.show()

# %%
grades = ['A', 'B', 'C', 'D', 'E', 'F']
students_count = [20, 30, 10, 5, 8, 2]
plt.bar(grades, students_count,
color=['green', 'gray', 'gray', 'gray',
'gray', 'red'])
plt.show()

# %%
plt.title('Grades Bar Plot for Biology Class')
plt.xlabel('Grade')
plt.ylabel('Num Students')
plt.bar(grades, students_count,
color=['green', 'gray', 'gray', 'gray',
'gray', 'red'])
plt.show()

# %%
plt.barh(grades, students_count,
color=['green', 'gray', 'gray', 'gray',
'gray', 'red'])
plt.show()
